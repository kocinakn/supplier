# %%
from tools import data_preparation as dp
from tools import connections
from tools import enumeration


import pandas as pd
import numpy as np
import requests
import datetime
import os
import sys

import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', 100)
pd.set_option('display.float_format', lambda x: '%.7f' % x)

# %%
df = dp.binance_spot_market_table(connections.connect_binance_spot_api())

# %%
busd = pd.DataFrame()

# %%
usdt = pd.DataFrame()

# %%
df.head()
# Out:
#     symbol            lastPrice          quoteVolume                count                 date
# 0   ETHBTC              0.06846          7,336.75982        205,222.00000  2023-01-25 17:09:54
# 1   LTCBTC              0.00388            237.44502         27,112.00000  2023-01-25 17:09:54
# 2   BNBBTC              0.01329            590.45718         67,344.00000  2023-01-25 17:09:54
# 3   NEOBTC              0.00034             11.91862          2,439.00000  2023-01-25 17:09:54
# 4  QTUMETH              0.00161              5.80380             93.00000  2023-01-25 17:09:54

# %%
for index, row in df.iterrows():
    if row['symbol'][-4:] == 'BUSD':
        busd.append(df.iloc[index, :])
    elif row['symbol'][-4:] == 'USDT':
        usdt.append(df.iloc[index, :])
    else:
        continue

# %%
busd.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
usdt.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.head(20)
# Out:
#      symbol            lastPrice          quoteVolume                count                 date
# 0    ETHBTC              0.06846          7,336.75982        205,222.00000  2023-01-25 17:09:54
# 1    LTCBTC              0.00388            237.44502         27,112.00000  2023-01-25 17:09:54
# 2    BNBBTC              0.01329            590.45718         67,344.00000  2023-01-25 17:09:54
# 3    NEOBTC              0.00034             11.91862          2,439.00000  2023-01-25 17:09:54
# 4   QTUMETH              0.00161              5.80380             93.00000  2023-01-25 17:09:54
# 5    EOSETH              0.00069             57.52910          1,048.00000  2023-01-25 17:09:54
# 6    SNTETH              0.00002            229.81539          1,510.00000  2023-01-25 17:09:54
# 7    BNTETH              0.00026             15.72831            135.00000  2023-01-25 17:09:54
# 8    BCCBTC              0.00000              0.00000              0.00000  2023-01-25 17:09:54
# ...

# %%
coingecko.show_api_ids_info(['1peco'])
# Out:
# 2023-02-22 13:57:09. Twitter: We successfully logged in.
#   symbol   name          last_tweet      platform  category     price   ath  ...  mcap  fdv  circ  max_supply  mcapfdv  circtotal          update_date
# 0  1PECO  1peco 2022-10-11 05:21:27  ['ethereum']       NaN  0.158198  4.34  ...   0.0  0.0   0.0         0.0      NaN        NaN  2023-02-22 13:57:10
#
# [1 rows x 16 columns]

# %%
from visualization.cfd import major_indexes

# %%
major_indexes.plot_indexes()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# <Mpf_Figure size 1800x1500 with 4 Axes>
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# C:\Programowanie\Anaconda\lib\site-packages\mplfinance\_arg_validators.py:35: UserWarning:
#
# ...
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
# ...

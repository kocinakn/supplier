# %%
from myscripts import defi_stats

import pandas as pd
import numpy as np
import requests
import datetime
import os
import sys

import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)

import os
print(os.getcwd())
# Out:
# C:\Users\kocin\Desktop\crypto\supplier\notebooks\reports

# %% [markdown]
# <font size="8">DEFI_ON_GIVEN_CHAIN</font>

# %%
dt = defi_stats.DefiOnGivenChain(save_in_psql=False, include_tvl_threshold=True, comparing_table='DefiDappsMarket').stats # or comparing_table = 'DefiDappsMarket'
# Out:
# 2023-07-12 12:13:33. Chains: 203
#
#
# ...

# %%
for k, v in dt.items():
    print(k)
    display(v)
# Out:
# xDai
#                      name symbol      gecko_id           category                  tvl                tvl_y            chain_tvl          chain_tvl_y       chain_tvl_perc          chain_share                 mcap                                             chains                 date               date_y
# 0            RealT Tokens      -             0                RWA     81,426,107.12000     81,426,107.12000     81,426,107.12000     81,426,107.12000              0.00000              1.00000              0.00000                                             [xDai]  2023-07-01 01:27:56  2023-07-01 01:27:47
# 1                   Agave   AGVE   agave-token            Lending     17,451,375.94417     17,451,375.94417     17,451,375.94417     17,451,375.94417              0.00000              1.00000        871,801.09427                                             [xDai]  2023-07-01 01:27:56  2023-07-01 01:27:47
# ...

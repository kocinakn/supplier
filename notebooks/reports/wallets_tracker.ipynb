# %%
from myscripts import wallets_tracker
from tools import data_preparation as dp
from tools import enumeration

import pandas as pd
import numpy as np
import requests
import datetime
import os
import sys

import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)

# %% [markdown]
# <font size="8">WALLETS_TRACKER</font>

# %%
wallets_tracker.WalletsTracker(save_transactions=True, apply_time_threshold=True)
# Out:
# 2023-10-21 20:42:34. Digits DAO: 0x0c1a3e4e1c3da4c89582dfa1afa87a1853d7f78f
# 2023-10-21 20:42:34. https://debank.com/profile/0x0c1a3e4e1c3da4c89582dfa1afa87a1853d7f78f
#        action     chain sends sends_value             receives       receives_value     counterparty          event_time
# 0        Swap  Ethereum     0           0     59210000.0 SHARK            935.21100  no_counterparty 2023-10-21 08:26:11
# 1  Airdropped   Polygon     0           0           1.0 5000$A              0.00000  no_counterparty 2023-10-21 07:51:27
# 2    NFT_Swap    Gnosis     0           0  1.0 drops-usdt.info              0.00000  no_counterparty 2023-10-21 06:50:30
# 3        Swap  Ethereum     0           0    258268580.0 FLOKI          2,206.10700  no_counterparty 2023-10-21 06:49:35
# 2023-10-21 20:42:41. Digits DAO - Multisig: 0x5ad44bf7d970eab4096b22c52621ae0c0ac46c46
# 2023-10-21 20:42:41. https://debank.com/profile/0x5ad44bf7d970eab4096b22c52621ae0c0ac46c46
# ...
